# %% [markdown]
# <h2 align="center"> Logistic Regression </h2>

# %% [markdown]
# ### Task 2: Load the Data and Libraries
# ---

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
plt.style.use("ggplot")
# %matplotlib inline

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 12, 8

# %%
data = pd.read_csv('DMV_Written_Tests.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 3 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   DMV_Test_1  100 non-null    float64
#  1   DMV_Test_2  100 non-null    float64
#  2   Results     100 non-null    int64
# dtypes: float64(2), int64(1)
# memory usage: 2.5 KB

# %%
scores = data[['DMV_Test_1', 'DMV_Test_2']].values
results = data['Results'].values

# %% [markdown]
# ### Task 3: Visualize the Data
# ---

# %%
passed = (results == 1).reshape(100, 1)
failed = (results == 0).reshape(100, 1)

ax = sns.scatterplot(x = scores[passed[0:, 0], 0],
                     y = scores[passed[0:, 0], 1],
                     marker = '^',
                     c = 'green',
                     s = 60)

sns.scatterplot(x = scores[failed[0:, 0], 0],
                y = scores[failed[0:, 0], 1],
                marker = 'X',
                c = ' red',
                s = 60)

ax.set(xlabel ='DMV Written test 1 score', ylabel = 'DMV Written test 2 score')
ax.lagend(['Passed', 'Failed'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-61-09494a576761> in <module>
#       2 failed = (results == 0).reshape(100, 1)
#       3
# ----> 4 ax = sns.scatterplot(x = scores[passed[0:, 0], 0],
#       5                      y = scores[passed[0:, 0], 1],
#       6                      marker = '^',
#
# ~\anaconda3\lib\site-packages\seaborn\relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#    1401         ax = plt.gca()
#    1402
# -> 1403     p.plot(ax, kwargs)
#    1404
#    1405     return ax
#
# ~\anaconda3\lib\site-packages\seaborn\relational.py in plot(self, ax, kws)
#     948
#     949         args = np.asarray(x), np.asarray(y), np.asarray(s), np.asarray(c)
# --> 950         points = ax.scatter(*args, **kws)
#     951
#     952         # Update the paths to get different marker shapes. This has to be
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*args, **kwargs)
#     356                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     357                 f"should be pass as keyword, not positionally.")
# --> 358         return func(*args, **kwargs)
#     359
#     360     return wrapper
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4399
#    4400         c, colors, edgecolors = \
# -> 4401             self._parse_scatter_color_args(
#    4402                 c, edgecolors, kwargs, x.size,
#    4403                 get_next_color_func=self._get_patches_for_fill.get_next_color)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in _parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4197         c_is_string_or_strings = (
#    4198             isinstance(c, str)
# -> 4199             or (isinstance(c, collections.abc.Iterable) and len(c) > 0
#    4200                 and isinstance(cbook.safe_first_element(c), str)))
#    4201
#
# TypeError: len() of unsized object

# %% [markdown]
# ### Task 4: Define the Logistic Sigmoid Function $\sigma(z)$
# ---
#
# $$ \sigma(z) = \frac{1}{1+e^{-z}}$$

# %%
def sigmoid(z):
    return 1/(1+np.exp(-z))

# %%
sigmoid(0)
# Out:
# 0.5

# %% [markdown]
# ### Task 5: Compute the Cost Function $J(\theta)$ and Gradient
# ---

# %% [markdown]
# The objective of logistic regression is to minimize the cost function
#
# $$J(\theta) = -\frac{1}{m} \sum_{i=1}^{m} [ y^{(i)}log(h_{\theta}(x^{(i)})) + (1 - y^{(i)})log(1 - (h_{\theta}(x^{(i)}))]$$
#
# where the gradient of the cost function is given by
#
# $$ \frac{\partial J(\theta)}{\partial \theta_j} = \frac{1}{m} \sum_{i=1}^{m} (h_{\theta}(x^{(i)}) - y^{(i)})x_j^{(i)}$$

# %%
def cost_compute(theta,x,y):
    m = len(y)
    h = sigmoid(np.dot(x, theta))
    error = (y*np.log(h)) + (1-y)*np.log(1-h)
    cost = -1/m * np.sum(error)
    grad = 1/m * np.dot(x.transpose(), (h-y))
    return cost, grad

# %% [markdown]
# ### Task 6: Cost and Gradient at Initialization
# ---

# %%
# Gradient before optimization process
score_mean = np.mean(scores,axis=0)
score_std = np.std(scores,axis=0)
scores = (scores - score_mean)/score_std

row = scores.shape[0]
col = scores.shape[1]

X = np.append(np.ones((row, 1)), scores, axis =1)
y = results.reshape(row, 1)

theta_init = np.zeros((col + 1, 1))
cost, grad = cost_compute(theta_init, X, y)
# score.shape

# %%
print('Cost at initialization', cost)
print('Gradient at initialization', grad)
# Out:
# Cost at initialization 0.6931471805599453
# Gradient at initialization [[-0.1       ]
#  [-0.28122914]
#  [-0.25098615]]

# %%
# n = np.zeros((col+1, 1))
# print(n)

# %% [markdown]
# ### Task 7: Gradient Descent
# ---

# %% [markdown]
# Minimize the cost function $J(\theta)$ by updating the below equation and repeat until convergence
# $\theta_j := \theta_j - \alpha \frac{\partial J(\theta)}{\partial \theta_j}$ (simultaneously update $\theta_j$ for all $j$)

# %%
def gradient_descent(theta, x, y, alpha, iteration):
    costs = []
349770294415848, 0.20349770292851438, 0.20349770291305103, 0.2034977028977662, 0.20349770288265792, 0.2034977028677241, 0.20349770285296276, 0.20349770283837187, 0.2034977028239495, 0.20349770280969373, 0.20349770279560261, 0.20349770278167412, 0.20349770276790666, 0.2034977027542981, 0.2034977027408467, 0.20349770272755055, 0.20349770271440812, 0.2034977027014173, 0.20349770268857664, 0.20349770267588427, 0.20349770266333844, 0.20349770265093753, 0.20349770263867978, 0.2034977026265636, 0.2034977026145874, 0.2034977026027494, 0.20349770259104824, 0.20349770257948216, 0.20349770256804967, 0.20349770255674915, 0.20349770254557914, 0.20349770253453822, 0.20349770252362467, 0.20349770251283722, 0.20349770250217433, 0.2034977024916346, 0.20349 ...

# %% [markdown]
# ### Task 8: Plotting the Convergence of $J(\theta)$
# ---

# %% [markdown]
# Plot $J(\theta)$ against the number of iterations of gradient descent:

# %%
plt.plot(costs)
plt.xlabel('Iteration')
plt.ylabel('$J(\Theta)$')
plt.title("Values of Cost function over Iteration of Gradient Descent")
# Out:
# Text(0.5, 1.0, 'Values of Cost function over Iteration of Gradient Descent')

# %% [markdown]
# ### Task 9: Plotting the decision boundary
# ---

# %% [markdown]
# $h_\theta(x) = \sigma(z)$, where $\sigma$ is the logistic sigmoid function and $z = \theta^Tx$
#
# When $h_\theta(x) \geq 0.5$ the model predicts class "1":
#
# $\implies \sigma(\theta^Tx) \geq 0.5$
#
# $\implies \theta^Tx \geq 0$ predict class "1"
#
# Hence, $\theta_1 + \theta_2x_2 + \theta_3x_3 = 0$ is the equation for the decision boundary, giving us
#
# $ x_3 = \frac{-(\theta_0+\theta_1x)}{\theta_2}$

# %%
passed = (results == 1).reshape(100, 1)
failed = (results == 0).reshape(100, 1)

ax = sns.scatterplot(x = X[passed[:, 0], 1],
                     y = X[passed[:, 0], 2],
                     marker = '^',
                     c = 'green',
                     s = 60)

sns.scatterplot(x = y[failed[:, 0], 1],
                y = y[failed[:, 0], 2],
                marker = 'X',
                c = ' red',
                s = 60)

x_boundary = np.array([np.min(X[:, 1]), np.max(X[:, 1])])
y_boundary = -(theta[0]+theta[1]*x_boundary)/theta[2]

sns.lineplot(x=x_boundary, y=y_boundary, c ='blue')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-86-71673f162fa8> in <module>
#       2 failed = (results == 0).reshape(100, 1)
#       3
# ----> 4 ax = sns.scatterplot(x = X[passed[:, 0], 1],
#       5                      y = X[passed[:, 0], 2],
#       6                      marker = '^',
#
# ~\anaconda3\lib\site-packages\seaborn\relational.py in scatterplot(x, y, hue, style, size, data, palette, hue_order, hue_norm, sizes, size_order, size_norm, markers, style_order, x_bins, y_bins, units, estimator, ci, n_boot, alpha, x_jitter, y_jitter, legend, ax, **kwargs)
#    1401         ax = plt.gca()
#    1402
# -> 1403     p.plot(ax, kwargs)
#    1404
#    1405     return ax
#
# ~\anaconda3\lib\site-packages\seaborn\relational.py in plot(self, ax, kws)
#     948
#     949         args = np.asarray(x), np.asarray(y), np.asarray(s), np.asarray(c)
# --> 950         points = ax.scatter(*args, **kws)
#     951
#     952         # Update the paths to get different marker shapes. This has to be
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1563     def inner(ax, *args, data=None, **kwargs):
#    1564         if data is None:
# -> 1565             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1566
#    1567         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*args, **kwargs)
#     356                 f"%(removal)s.  If any parameter follows {name!r}, they "
#     357                 f"should be pass as keyword, not positionally.")
# --> 358         return func(*args, **kwargs)
#     359
#     360     return wrapper
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4399
#    4400         c, colors, edgecolors = \
# -> 4401             self._parse_scatter_color_args(
#    4402                 c, edgecolors, kwargs, x.size,
#    4403                 get_next_color_func=self._get_patches_for_fill.get_next_color)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in _parse_scatter_color_args(c, edgecolors, kwargs, xsize, get_next_color_func)
#    4197         c_is_string_or_strings = (
#    4198             isinstance(c, str)
# -> 4199             or (isinstance(c, collections.abc.Iterable) and len(c) > 0
#    4200                 and isinstance(cbook.safe_first_element(c), str)))
#    4201
#
# TypeError: len() of unsized object

# %% [markdown]
# ### Task 10: Predictions using the optimized $\theta$ values
# ---

# %% [markdown]
# $h_\theta(x) = x\theta$

# %%
def predict(theta, x):
    results = sigmoid(X.dot(theta))
    return results>0

p = predict(theta, X)
print('Training accuracy: ', np.sum(p==y), '%')
# Out:
# Training accuracy:  60 %

# %%
def fit(test):
    test = (test - score_mean)/score_std
    test = np.append(np.ones(1), test)
    probability = sigmoid(test.dot(theta))
    return probability
score = np.array([50,70])
probability = fit(score)

print('By judging the scores in their DMV written test, probability of passing is:', np.round(probability[0], 2))
# Out:
# By judging the scores in their DMV written test, probability of passing is: 0.32
